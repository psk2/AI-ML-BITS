# %%
import pandas as pd
import re

# to display the total number columns present in the dataset
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv("products.csv");
df.head()
# Out:
#                                         Product_Name         Brand  \
# 0     Cadbury Bournvita Health Drink Nutrition Drink       Cadbury
# 1       Betty Crocker Triple Choco Brownie Mix 425 g         Betty
# 2                                       Madhur Sugar  Madhur Sugar
# 3          Fortune Sunlite Refined Sunflower Oil Can       Fortune
# 4  Emami Healthy & Tasty Kachchi Ghani Mustard Oi...         Emami
#
#    Discounted_Price  Discount  Original_Price  Product_Rating  No_of_ratings  \
# 0             286.0       1.0           290.0             4.5          11923
# 1             322.0       2.0           330.0             4.4            294
# 2              48.0      12.0            55.0             4.5          17460
# 3             591.0      13.0           685.0             4.5           1660
# 4             133.0      14.0           155.0             4.4           1138
#
#                                          Product_URL  Platform
# 0  https://www.flipkart.com/cadbury-bournvita-hea...  Flipkart
# 1  https://www.flipkart.com/betty-crocker-triple-...  Flipkart
# 2  https://www.flipkart.com/madhur-sugar/p/itmevj...  Flipkart
# 3  https://www.flipkart.com/fortune-sunlite-refin...  Flipkart
# 4  https://www.flipkart.com/emami-healthy-tasty-k...  Flipkart

# %%
df["Discounted_Price"].max()
# Out:
# 10919.0

# %%
query_string = input("Enter some value: ").lower()
# Out:
# Enter some value: sugar

# %%
cond1 = df[df['Product_Name'].str.lower().str.contains(query_string)] 
# cond1 = cond1.sort_values(by=['Discounted_Price'], ascending=True)
cond1.sort_values(['Discounted_Price', 'Product_Rating'], ascending=[True, False])
# .reset_index(drop=True)

cond2 = cond1

# cond2 = cond2.reset_index(drop=True)
# cond2.head(1)
cond2
print(list(cond2.index.values))
# Out:
# [2, 5, 20, 44, 69, 71, 83, 84, 90, 105, 106, 155, 214, 231, 585, 843, 1009, 1010, 1014, 1024]

# %%
cond2.iloc[1:5]
# Out:
#                              Product_Name     Brand  Discounted_Price  \
# 5               Parry's White Label Sugar   Parry's              59.0
# 20        Flipkart Supermart Select Sugar  Flipkart              59.0
# 44  Sugar Free Gold 500 Pellets Sweetener     Sugar             237.0
# 69            Sugar Free Natura Sweetener     Sugar             137.0
#
#     Discount  Original_Price  Product_Rating  No_of_ratings  \
# 5        1.0            60.0             4.4           4625
# 20      34.0            90.0             4.5            787
# 44       5.0           250.0             4.6            557
# 69       3.0           142.0             4.5            363
#
#                                           Product_URL  Platform
# 5   https://www.flipkart.com/parry-s-white-label-s...  Flipkart
# 20  https://www.flipkart.com/flipkart-supermart-se...  Flipkart
# 44  https://www.flipkart.com/sugar-free-gold-500-p...  Flipkart
# 69  https://www.flipkart.com/sugar-free-natura-swe...  Flipkart

# %%
def make_clickable_both(val): 
    return f'<a target="_blank"  href="{val}"><button>Click here to buy</button></a>'

cond2.reset_index().style.format({'Product_URL': make_clickable_both})
# Out:
# <style  type="text/css" >
# </style><table id="T_1b2f172c_a8bf_11ea_8d6e_24fd52b1b921" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >Product_Name</th>        <th class="col_heading level0 col2" >Brand</th>        <th class="col_heading level0 col3" >Discounted_Price</th>        <th class="col_heading level0 col4" >Discount</th>        <th class="col_heading level0 col5" >Original_Price</th>        <th class="col_heading level0 col6" >Product_Rating</th>        <th class="col_heading level0 col7" >No_of_ratings</th>        <th class="col_heading level0 col8" >Product_URL</th>        <th class="col_heading level0 col9" >Platform</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1b2f172c_a8bf_11ea_8d6e_24fd52b1b921level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1b2f172c_a8bf_11ea_8d6e_24fd52b1b921row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_1b2f172c_a8bf_11ea_8d6e_24fd52b1b921row0_col1" class="data row0 col1" >Madhur Sugar</td>
#                         <td id="T_1b2f172c_a8bf_11ea_8d6e_24fd52b1b921row0_col2" class="data row0 col2" >Madhur Sugar</td>
#                         <td id="T_1b2f172c_a8bf_11ea_8d6e_24fd52b1b921row0_col3" class="data row0 col3" >48.000000</td>
#                         <td id="T_1b2f172c_a8bf_11ea_8d6e_24fd52b1b921row0_col4" class="data row0 col4" >12.000000</td>
#                         <td id="T_1b2f172c_a8bf_11ea_8d6e_24fd52b1b921row0_
="T_1b2f172c_a8bf_11ea_8d6e_24fd52b1b921level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_1b2f172c_a8bf_11ea_8d6e_24fd52b1b921row4_col0" class="data row4 col0" >4</td>
#                         <td id="T_1b2f172c_a8bf_11ea_8d6e_24fd52b1b921row4_col1" class="data row4 col1" >Sugar Free Natura Sweetener</td>
#                         <td id="T_1b2f172c_a8bf_

# %%
#GUI Part
#Please install tkinter module [pip install tkinter]
#Also please install pandastable module [pip install pandastable]

from tkinter import *
from tkinter import ttk
from pandastable import Table, TableModel
import tkinter.messagebox as MessageBox
import webbrowser
    
def fetch_super_details():
    newWindow = Toplevel(root) 
#     pt = Table(newWindow)
#     pt.show()
    class TestApp(Frame):
        def __init__(self, parent=newWindow):
            self.parent = parent
            Frame.__init__(self)
            self.main = self.master
            self.main.geometry('600x400+200+100')
            self.main.title('Products Details')
            f = Frame(self.main)
            f.pack(fill=BOTH,expand=1)
            df = TableModel.getSampleData()
            self.table = newWindow = Table(f, dataframe=products_df,showtoolbar=True, showstatusbar=True)
            newWindow.show()
            return    
    TestApp()

def get():
        for i in tree.get_children():
            tree.delete(i)
        result = []
        product = product_id.get()
        product = product.split(" ")[0]
        if product == "":
            MessageBox.showinfo("Oh Crap!!","Product name is required for getting details")
        else:   
            for index, row in products_df.iterrows():
                if product.lower() in row['Product_Name'].lower():
                    result.append(index)
            if len(result) == 0:
                 MessageBox.showinfo("Oh Crap!!","Could not find any realted product. Try Again")
            else:
                for x in result:
                    p = products_df.iloc[x]['Product_Name']
                    b = products_df.iloc[x]['Brand']
                    dp = "Rs." + str(products_df.iloc[x]['Discounted_Price'])
                    d = str(products_df.iloc[x]['Discount']) + "%"
                    op = "Rs." + str(products_df.iloc[x]['Original_Price'])
                    pr = products_df.iloc[x]['Product_Rating']
                    nor = products_df.iloc[x]['No_of_ratings']
                    purl = products_df.iloc[x]['Product_URL']
                    plat = products_df.iloc[x]['Platform']
                    tree.insert("","end",values=(p,b,dp,d,op,pr,nor,purl,plat))

recommended_product = {}
                    
def suggest():
        for i in tree1.get_children():
            tree1.delete(i)
        result1 = []
        query_string = product_id.get()
        query_string = query_string.split(" ")[0].lower()
        if query_string == "":
            MessageBox.showinfo("Oh Crap!!","Product name is required for getting recommendations")
        else:   
            cond1 = products_df[products_df['Product_Name'].str.lower().str.contains(query_string)] 
            # cond1 = cond1.sort_values(by=['Discounted_Price'], ascending=True)
            cond1.sort_values(['Discounted_Price', 'Product_Rating'], ascending=[True, False]).reset_index(drop=True)

            cond2 = cond1
            for x in list(cond2.head(5).index.values):
                    p = products_df.iloc[x]['Product_Name']
                    b = products_df.iloc[x]['Brand']
                    dp = "Rs." + str(products_df.iloc[x]['Discounted_Price'])
                    d = str(products_df.iloc[x]['Discount']) + "%"
                    op = "Rs." + str(products_df.iloc[x]['Original_Price'])
                    pr = products_df.iloc[x]['Product_Rating']
                    nor = products_df.iloc[x]['No_of_ratings']
#                     val = products_df.iloc[x]['Product_URL']
                    val = 'Click here to buy'
                    plat = products_df.iloc[x]['Platform']
                    tree1.insert("","end",values=(p,b,dp,d,op,pr,nor,val,plat))
                    recommended_product[p] = products_df.iloc[x]['Product_URL']
  
        
root = Tk()
root.geometry("1490x1000")
# root.resizable(0, 0)
# root.geometry("")
root.title("Product Recommender")

id = Label(root, text='Enter Product', font=('bold',10))
id.place(x=20,y=30)

product_id = Entry()
product_id.place(x=150,y=30)

# ================================================================================================

p2 = Label(root, text='Recommended Product Details', font=('bold',10))
p2.place(x=20,y=80)
frame1 = Frame(root,bg='grey',bd=3)
frame1.place(x=20,y=120)

tree1 = ttk.Treeview(frame1, columns = (1,2,3,4,5,6,7,8,9), height = 5,show = "headings")
tree1.pack(side = 'left')

tree1.heading(1, text="Product_Name")
tree1.heading(2, text="Brand")
tree1.heading(3, text="Discounted_Price")
tree1.heading(4, text="Discount")
tree1.heading(5, text="Original_Price")
tree1.heading(6, text="Product_Rating")
tree1.heading(7, text="No_of_ratings")
tree1.heading(8, text="Product_URL")
tree1.heading(9, text="Platform")

tree1.column(1, width = 250)
tree1.column(2, width = 120)
tree1.column(3, width = 100)
tree1.column(4, width = 100)
tree1.column(5, width = 100)
tree1.column(6, width = 100)
tree1.column(7, width = 100)
tree1.column(8, width = 300)
tree1.column(9, width = 90)

###############################################################################

# vsb = ttk.Scrollbar(frame,orient="vertical",command=tree.yview)
# vsb.pack(side = 'right', fill = 'y')
# hsb = ttk.Scrollbar(frame,orient="horizontal",command=tree.xview)
# hsb.pack(side = 'bottom', fill = 'x')
# tree.configure(yscrollcommand=vsb.set,xscrollcommand=hsb.set)


#############################################################################

p1 = Label(root, text='All Related Products', font=('bold',10))
p1.place(x=20,y=350)
frame = Frame(root,bg='grey',bd=3)
frame.place(x=20,y=390)

tree = ttk.Treeview(frame, columns = (1,2,3,4,5,6,7,8,9), height = 7,show = "headings")
tree.pack(side = 'left')

tree.heading(1, text="Product_Name")
tree.heading(2, text="Brand")
tree.heading(3, text="Discounted_Price")
tree.heading(4, text="Discount")
tree.heading(5, text="Original_Price")
tree.heading(6, text="Product_Rating")
tree.heading(7, text="No_of_ratings")
tree.heading(8, text="Product_URL")
tree.heading(9, text="Platform")

tree.column(1, width = 250)
tree.column(2, width = 120)
tree.column(3, width = 100)
tree.column(4, width = 100)
tree.column(5, width = 100)
tree.column(6, width = 100)
tree.column(7, width = 100)
tree.column(8, width = 300)
tree.column(9, width = 90)

scroll = ttk.Scrollbar(frame, orient="vertical", command=tree.yview)
scroll.pack(side = 'right', fill = 'y')
tree.configure(yscrollcommand=scroll.set)
############################################################################
new = 1
def openweb(url):
    webbrowser.open(url,new=new)


def selectItem(a):
    curItem = tree1.focus()
    openweb(recommended_product[tree1.item(curItem)['values'][0]])
    
tree1.bind('<ButtonRelease-1>', selectItem)

#############################################################################      

getbutton = Button(root, text="Fetch All", font=('italic',10),fg='white' ,bg="#BB8FCE", height=1,width=7,command=get)
getbutton.place(x=600,y=30)


suggest = Button(root, text="Get Recommendations", font=('italic',10),fg='white' ,bg="#F4D03F", height=1,width=20,command=suggest)
suggest.place(x=300,y=30)

super_button = Button(root, text="Products Handler", font=('italic',10), fg="white",bg="#F1948A", command=fetch_super_details)
super_button.place(x=1100,y=30)

close = Button(root, text="Exit", font=('bold',10), fg='#17202a',bg="#76D7C4", height = 1, width = 4,compound="c" ,command=root.destroy)
close.place(x=630,y=650)

def on_enter(e):
    getbutton['background'] = 'green'

def on_leave(e):
    getbutton['background'] = '#BB8FCE'

getbutton.bind("<Enter>", on_enter)
getbutton.bind("<Leave>", on_leave)


def on_enter(e):
    super_button['background'] = 'green'

def on_leave(e):
    super_button['background'] = '#F1948A'

super_button.bind("<Enter>", on_enter)
super_button.bind("<Leave>", on_leave)

def on_enter(e):
    suggest['background'] = 'green'

def on_leave(e):
    suggest['background'] = '#F4D03F'

suggest.bind("<Enter>", on_enter)
suggest.bind("<Leave>", on_leave)

def on_enter(e):
    close['background'] = 'green'

def on_leave(e):
    close['background'] = '#76D7C4'

close.bind("<Enter>", on_enter)
close.bind("<Leave>", on_leave)

root.configure(bg='#17202A')
root.mainloop()
